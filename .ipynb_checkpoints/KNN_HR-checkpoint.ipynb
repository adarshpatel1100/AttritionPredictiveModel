# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
path="C:/Users/ABC/Desktop/HR1.csv"

# %%
headernames = ['Age','DailyRate','DistanceFromHome','Education' ,'EmployeeNumber',
             'EnvironmentSatisfaction','HourlyRate','JobInvolvement','JobLevel','JobSatisfaction',
             'MonthlyIncome','MonthlyRate','NumCompaniesWorked','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction',
             'StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager','Attrition'
]

# %%
dataset = pd.read_csv(path, names = headernames)

# %%
dataset
# Out:
#     Age  DailyRate  DistanceFromHome  Education  EmployeeNumber  \
# 0    41       1102                 1          2               1
# 1    49        279                 8          1               2
# 2    37       1373                 2          2               4
# 3    33       1392                 3          4               5
# 4    27        591                 2          1               7
# 5    32       1005                 2          2               8
# 6    59       1324                 3          3              10
# 7    30       1358                24          1              11
# 8    38        216                23          3              12
# 9    36       1299                27          3              13
# 10   35        809                16          3              14
# 11   29        153                15          2              15
# 12   31        670                26          1              16
# 13   34       1346                19          2              18
# 14   28        103                24          3              19
# 15   29       1389                21          4              20
# 16   32        334                 5          2              21
# 17   22       1123                16          2              22
# 18   53       1219                 2          4              23
# 19   38        371                 2          3              24
# 20   24        673                11          2              26
# 21   36       1218                 9          4              27
# 22   34        419                 7          4              28
# 23   21        391                15          2              30
# 24   34        699                 6          1              31
# 25   53       1282                 5          3              32
# 26   32       1125                16          1              33
# 27   42        691                 8          4              35
# 28   44        477                 7          4              36
# 29   46        705                 2          4              38
# ..  ...        ...               ...        ...             ...
# 70   59       1225                 1          1              91
# 71   29       1328                 2          3              94
# 72   31       1082                 1          4              95
# 73   32        548                 1          3              96
# 74   36        132                 6          3              97
# 75   31        746                 8          4              98
# 76   35        776                 1          4             100
# 77   45        193                 6          4             101
# 78   37        397                 7          4             102
# 79   46        945                 5          2             103
# 80   30        852                 1          1             104
# 81   35       1214                 1          3             105
# 82   55        111                 1          2             106
# 83   38        573                 6          3             107
# 84   34       1153                 1          2             110
# 85   56       1400                 7          3             112
# 86   23        541                 2          1             113
# 87   51        432                 9          4             116
# 88   30        288                 2          3             117
# 89   46        669                 9          2             118
# 90   40        530                 1          4             119
# 91   51        632                21          4             120
# 92   30       1334                 4          2             121
# 93   46        638                 1          3             124
# 94   32       1093                 6          4             125
# 95   54       1217                 2          4             126
# 96   24       1353                 3          2             128
# 97   28        120                 4          3             129
# 98   58        682                10          4             131
# 99   44        489                23          3             132
#
#     EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                         2          94               3         2
# 1                         3          61               2         2
# 2                         4          92               2         1
# 3                         4          56               3         1
# 4                         1          40               3         1
# 5                         4          79               3         1
# 6                         3          81               4         1
# 7                         4          67               3         1
# 8                         4          44               2         3
# 9                         3          94               3         2
# 10                        1          84               4         1
# 11                        4          49               2         2
# 12                        1          31               3         1
# 13                        2          93               3         1
# 14                        3          50               2         1
# 15                        2          51               4         3
# 16                        1          80               4         1
# 17                        4          96               4         1
# 18                        1          78               2         4
# 19                        4          45               3         1
# 20                        1          96               4         2
# 21                        3          82               2         1
# 22                        1          53               3         3
# 23                        3          96               3         1
# 24                        2          83               3         1
# 25                        3          58               3         5
# 26                        2          72               1         1
# 27                        3          48               3         2
# 28                        1          42               2         3
# 29                        2          83               3         5
# ..                      ...         ...             ...       ...
# 70                        1          57               2         2
# 71                        3          76               3         1
# 72                        3          87               3         1
# 73                        2          66               3         2
# 74                        2          55               4         1
# 75                        3          61               3         2
# 76                        3          32               2         2
# 77                        4          52               3         3
# 78                        1          30               3         3
# 79                        2          80               3         2
# 80                        4          55               2         2
# 81                        2          30               2         1
# 82                        1          70               3         3
# 83                        2          79               1         2
# 84                        1          94               3         2
# 85                        4          49               1         3
# 86                        3          62               3         1
# 87                        4          96               3         1
# 88                        3          99               2         2
# 89                        3          64               2         3
# 90                        3          78               2         4
# 91                        3          71               3         2
# 92                        3          63               2         2
# 93                        3          40               2         3
# 94                        2          87               3         2
# 95                        1          60               3         3
# 96                        1          33               3         2
# 97                        2          43               3         2
# 98                        4          37               3         4
# 99                        2          67               3         2
#
#     JobSatisfaction    ...      RelationshipSatisfaction  StockOptionLevel  \
# 0                 4    ...                             1                 0
# 1                 2    ...                             4                 1
# 2                 3    ...                             2                 0
# 3                 3    ...                             3                 0
# 4                 2    ...                             4                 1
# 5                 4    ...                             3                 0
# 6                 1    ...                             1                 3
# 7                 3    ...                             2                 1
# 8                 3    ...                             2                 0
# 9                 3    ...                             2                 2
# 10                2    ...                             3                 1
# 11                3    ...                             4                 0
# 12                3    ...                             4                 1
# 13                4    ...                             3                 1
# 14                3    ...                             2                 0
# 15                1    ...                             3                 1
# 16                2    ...                             4                 2
# 17                4    ...                             2                 2
# 18                4    ...                             3                 0
# 19                4    ...                             3                 0
# 20                3    ...                             4                 1
# 21                1    ...                             2                 0
# 22                2    ...                             3                 0
# 23                4    ...                             4                 0
# 24                1    ...                             3                 0
# 25                3    ...                             4                 1
# 26                1    ...                             2                 0
# 27                2    ...                             4                 1
# 28                4    ...                             4                 1
# 29                1    ...                             4                 0
# ..              ...    ...                           ...               ...
# 70                3    ...                             4                 0
# 71                2    ...                             4                 1
# 72                2    ...                             2                 0
# 73                2    ...                             2                 2
# 74                4    ...                             2                 0
# 75                4    ...                             4                 0
# 76                1    ...                             2                 0
# 77                1    ...                             2                 0
# 78                3    ...                             1                 0
# 79                2    ...                             4                 1
# 80                4    ...                             3                 2
# 81                3    ...                             1                 0
# 82                4    ...                             4                 1
# 83                4    ...                             4                 3
# 84                2    ...                             3                 0
# 85                4    ...                             1                 0
# 86                1    ...                             3                 1
# 87                4    ...                             2                 2
# 88                4    ...                             1                 3
# 89                4    ...                             4                 0
# 90                2    ...                             4                 1
# 91                4    ...                             4                 0
# 92                2    ...                             2                 3
# 93                1    ...                             3                 1
# 94                3    ...                             1                 0
# 95                3    ...                             1                 1
# 96                3    ...                             1                 1
# 97                3    ...                             2                 0
# 98                3    ...                             3                 0
# 99                2    ...                             3                 1
#
#     TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                   8                      0                1               6
# 1                  10                      3                3              10
# 2                   7                      3                3               0
# 3                   8                      3                3               8
# 4                   6                      3                3               2
# 5                   8                      2                2               7
# 6                  12                      3                2               1
# 7                   1                      2                3               1
# 8                  10                      2                3               9
# 9                  17                      3                2               7
# 10                  6                      5                3               5
# 11                 10                      3                3               9
# 12                  5                      1                2               5
# 13                  3                      2                3               2
# 14                  6                      4                3               4
# 15                 10                      1                3              10
# 16                  7                      5                2               6
# 17                  1                      2                2               1
# 18                 31                      3                3              25
# 19                  6                      3                3               3
# 20                  5                      5                2               4
# 21                 10                      4                3               5
# 22                 13                      4                3              12
# 23                  0                      6                3               0
# 24                  8                      2                3               4
# 25                 26                      3                2              14
# 26                 10                      5                3              10
# 27                 10                      2                3               9
# 28                 24                      4                3              22
# 29                 22                      2                2               2
# ..                ...                    ...              ...             ...
# 70                 20                      2                2               4
# 71                  6                      3                3               5
# 72                  1                      4                3               1
# 73                 10                      3                3              10
# 74                  5                      3                3               1
# 75                 11                      2                3              11
# 76                 16                      2                3              15
# 77                 17                      3                4               0
# 78                 16                      3                4               5
# 79                 16                      2                3               4
# 80                 10                      1                2              10
# 81                  6                      3                3               6
# 82                 24                      4                3               1
# 83                 17                      3                3              13
# 84                  5                      2                3               5
# 85                 37                      3                2               6
# 86                  3                      3                3               0
# 87                 10                      4                3               4
# 88                 11                      3                3              11
# 89                  9                      3                3               9
# 90                 22                      3                2              22
# 91                 11                      2                1              10
# 92                 11                      4                2              11
# 93                 21                      5                2              10
# 94                 12                      0                3              11
# 95                 16                      5                1               4
# 96                  4                      2                2               3
# 97                  5                      3                4               5
# 98                 38                      1                2              37
# 99                 17                      3                4               3
#
#     YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                    4                        0                     5
# 1                    7                        1                     7
# 2                    0                        0                     0
# 3                    7                        3                     0
# 4                    2                        2                     2
# 5                    7                        3                     6
# 6                    0                        0                     0
# 7                    0                        0                     0
# 8                    7                        1                     8
# 9                    7                        7                     7
# 10                   4                        0                     3
# 11                   5                        0                     8
# 12                   2                        4                     3
# 13                   2                        1                     2
# 14                   2                        0                     3
# 15                   9                        8                     8
# 16                   2                        0                     5
# 17                   0                        0                     0
# 18                   8                        3                     7
# 19                   2                        1                     2
# 20                   2                        1                     3
# 21                   3                        0                     3
# 22                   6                        2                    11
# 23                   0                        0                     0
# 24                   2                        1                     3
# 25                  13                        4                     8
# 26                   2                        6                     7
# 27                   7                        4                     2
# 28                   6                        5                    17
# 29                   2                        2                     1
# ..                 ...                      ...                   ...
# 70                   3                        1                     3
# 71                   4                        0                     4
# 72                   1                        1                     0
# 73                   4                        0                     9
# 74                   0                        0                     0
# 75                   7                        1                     8
# 76                  13                        2                     8
# 77                   0                        0                     0
# 78                   2                        0                     2
# 79                   2                        0                     2
# 80                   8                        3                     0
# 81                   4                        0                     4
# 82                   0                        1                     0
# 83                  11                        1                     9
# 84                   2                        1                     3
# 85                   4                        0                     2
# 86                   0                        0                     0
# 87                   2                        0                     3
# 88                  10                       10                     8
# 89                   8                        4                     7
# 90                   3                       11                    11
# 91                   7                        1                     0
# 92                   8                        2                     7
# 93                   9                        9                     5
# 94                   8                        5                     7
# 95                   3                        0                     3
# 96                   2                        0                     2
# 97                   4                        0                     4
# 98                  10                        1                     8
# 99                   2                        1                     2
#
#     Attrition
# 0         Yes
# 1          No
# 2         Yes
# 3          No
# 4          No
# 5          No
# 6          No
# 7          No
# 8          No
# 9          No
# 10         No
# 11         No
# 12         No
# 13         No
# 14        Yes
# 15         No
# 16         No
# 17         No
# 18         No
# 19         No
# 20         No
# 21        Yes
# 22         No
# 23         No
# 24        Yes
# 25         No
# 26        Yes
# 27         No
# 28         No
# 29         No
# ..        ...
# 70         No
# 71         No
# 72         No
# 73         No
# 74         No
# 75         No
# 76         No
# 77         No
# 78         No
# 79         No
# 80         No
# 81         No
# 82         No
# 83         No
# 84         No
# 85         No
# 86         No
# 87         No
# 88         No
# 89        Yes
# 90         No
# 91         No
# 92         No
# 93         No
# 94         No
# 95         No
# 96         No
# 97         No
# 98         No
# 99         No
#
# [100 rows x 25 columns]

# %%
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,24].values

# %%
y
# Out:
# array(['Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes',
#        'No', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No',
#        'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Yes',
#        'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.20,random_state=7)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=10)
classifier.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#            weights='uniform')

# %%
y_pred=classifier.predict(x_test)`

# %%
y_pred
# Out:
# array(['No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No'], dtype=object)

# %% [markdown]
# # Accuracy

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 90.0

# %% [markdown]
# # Precision

# %%
from sklearn.metrics import precision_score
print(precision_score(y_test, y_pred, average="macro"))
# Out:
# 0.45
# C:\Users\ABC\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# # Recall

# %%
from sklearn.metrics import recall_score
print(recall_score(y_test, y_pred, average="macro"))
# Out:
# 0.5

# %%
yes=dataset.loc[dataset.Attrition == 'Yes','Attrition'].count()
yes
# Out:
# 15

# %%
no=dataset.loc[dataset.Attrition == 'No','Attrition'].count()

# %%
no
# Out:
# 85

# %%
y_test
# Out:
# array(['No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No'],
#       dtype=object)

# %%
type(y_test)
# Out:
# numpy.ndarray

# %%
y_test = pd.DataFrame(y_test, columns = ['Attrition'])

# %%
y_test
# Out:
#    Attrition
# 0         No
# 1        Yes
# 2         No
# 3         No
# 4         No
# 5         No
# 6         No
# 7         No
# 8         No
# 9         No
# 10        No
# 11        No
# 12        No
# 13        No
# 14        No
# 15       Yes
# 16        No
# 17        No
# 18        No
# 19        No

# %%
yytestyes=y_test.loc[y_test.Attrition == 'Yes','Attrition'].count()
yytestyes
# Out:
# 2

# %%
yytestno=y_test.loc[y_test.Attrition == 'No','Attrition'].count()
yytestno
# Out:
# 18

# %%
y_pred = pd.DataFrame(y_pred, columns = ['Attrition_Pred'])

# %%
y_pred
# Out:
#    Attrition_Pred
# 0              No
# 1              No
# 2              No
# 3              No
# 4              No
# 5              No
# 6              No
# 7              No
# 8              No
# 9              No
# 10             No
# 11             No
# 12             No
# 13             No
# 14             No
# 15             No
# 16             No
# 17             No
# 18             No
# 19             No

# %%
yypredno=y_pred.loc[y_pred.Attrition_Pred == 'No','Attrition_Pred'].count()
yypredno
# Out:
# 20

# %%
yypredyes=y_pred.loc[y_pred.Attrition_Pred == 'Yes','Attrition_Pred'].count()
yypredyes
# Out:
# 0

# %%
prediction= 'Yes','No'
datasetviz=[yes,no]
testviz=[yytestyes,yytestno]
predviz=[yypredyes,yypredno]

# %% [markdown]
# # Graph For Whole Dataset

# %%
plt.pie(datasetviz, labels=prediction, colors=['red','orange'])
# Out:
# ([<matplotlib.patches.Wedge at 0xfa65a90>,
#   <matplotlib.patches.Wedge at 0xfa6f048>],
#  [Text(0.9801071672559598, 0.4993895680663527, 'Yes'),
#   Text(-0.9801071204997298, -0.49938965983060607, 'No')])

# %% [markdown]
# # Graph For Y TEST

# %%
plt.pie(testviz, labels=prediction)
# Out:
# ([<matplotlib.patches.Wedge at 0xfa9e5c0>,
#   <matplotlib.patches.Wedge at 0xfa9eb00>],
#  [Text(1.0461621663333946, 0.3399186987098808, 'Yes'),
#   Text(-1.0461621902025062, -0.33991862524830146, 'No')])

# %% [markdown]
# # Graph FOR Y_PRE

# %%
plt.pie(predviz, labels=prediction)
# Out:
# ([<matplotlib.patches.Wedge at 0xfada128>,
#   <matplotlib.patches.Wedge at 0xfada668>],
#  [Text(1.1, 0.0, 'Yes'), Text(-1.1, 1.3471114790620887e-16, 'No')])
