# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
path="C:/Users/ABC/Desktop/HR1.csv"

# %%
headernames = ['Age','DailyRate','DistanceFromHome','Education' ,'EmployeeNumber',
             'EnvironmentSatisfaction','HourlyRate','JobInvolvement','JobLevel','JobSatisfaction',
             'MonthlyIncome','MonthlyRate','NumCompaniesWorked','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction',
             'StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager','Attrition'
]

# %%
dataset = pd.read_csv(path, names = headernames)

# %%
dataset
# Out:
#     Age  DailyRate  DistanceFromHome  Education  EmployeeNumber  \
# 0    41       1102                 1          2               1
# 1    49        279                 8          1               2
# 2    37       1373                 2          2               4
# 3    33       1392                 3          4               5
# 4    27        591                 2          1               7
# 5    32       1005                 2          2               8
# 6    59       1324                 3          3              10
# 7    30       1358                24          1              11
# 8    38        216                23          3              12
# 9    36       1299                27          3              13
# 10   35        809                16          3              14
# 11   29        153                15          2              15
# 12   31        670                26          1              16
# 13   34       1346                19          2              18
# ...

# %%
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,24].values

# %%
y
# Out:
# array(['Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes',
#        'No', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No',
#        'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Yes',
#        'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.30,random_state=8)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=7)
classifier.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#            weights='uniform')

# %%
import pickle as pk
with open('knnclass.pkl','wb') as fw:
    pk.dump(classifier,fw)

# %%
y_pred=classifier.predict(x_test)

# %%
y_pred
# Out:
# array(['No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No'], dtype=object)

# %% [markdown]
# # Accuracy

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 96.66666666666667

# %% [markdown]
# # Precision

# %%
from sklearn.metrics import precision_score
print(precision_score(y_test, y_pred, average="macro"))
# Out:
# 0.9827586206896552

# %% [markdown]
# # Recall

# %%
from sklearn.metrics import recall_score
print(recall_score(y_test, y_pred, average="macro"))
# Out:
# 0.75

# %%
yes=dataset.loc[dataset.Attrition == 'Yes','Attrition'].count()
yes
# Out:
# 15

# %%
no=dataset.loc[dataset.Attrition == 'No','Attrition'].count()

# %%
no
# Out:
# 85

# %%
y_test
# Out:
# array(['No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No'], dtype=object)

# %%
type(y_test)
# Out:
# numpy.ndarray

# %%
y_test = pd.DataFrame(y_test, columns = ['Attrition'])

# %%
y_test
# Out:
#    Attrition
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
# 5         No
# 6         No
# 7         No
# 8         No
# 9        Yes
# 10        No
# 11        No
# 12        No
# 13        No
# 14        No
# 15        No
# 16        No
# 17        No
# 18        No
# 19        No
# 20        No
# 21        No
# 22        No
# 23       Yes
# 24        No
# 25        No
# 26        No
# 27        No
# 28        No
# 29        No

# %%
yytestyes=y_test.loc[y_test.Attrition == 'Yes','Attrition'].count()
yytestyes
# Out:
# 2

# %%
yytestno=y_test.loc[y_test.Attrition == 'No','Attrition'].count()
yytestno
# Out:
# 28

# %%
y_pred = pd.DataFrame(y_pred, columns = ['Attrition_Pred'])

# %%
y_pred
# Out:
#    Attrition_Pred
# 0              No
# 1              No
# 2              No
# 3              No
# 4              No
# 5              No
# 6              No
# 7              No
# 8              No
# 9             Yes
# 10             No
# 11             No
# 12             No
# 13             No
# 14             No
# 15             No
# 16             No
# 17             No
# 18             No
# 19             No
# 20             No
# 21             No
# 22             No
# 23             No
# 24             No
# 25             No
# 26             No
# 27             No
# 28             No
# 29             No

# %%
yypredno=y_pred.loc[y_pred.Attrition_Pred == 'No','Attrition_Pred'].count()
yypredno
# Out:
# 29

# %%
yypredyes=y_pred.loc[y_pred.Attrition_Pred == 'Yes','Attrition_Pred'].count()
yypredyes
# Out:
# 1

# %%
prediction= 'Yes','No'
datasetviz=[yes,no]
testviz=[yytestyes,yytestno]
predviz=[yypredyes,yypredno]

# %%
plt.pie(datasetviz, labels=prediction, colors=['red','orange'])
# Out:
# ([<matplotlib.patches.Wedge at 0x13d7d518>,
# ...
#  [Text(0.9801071672559598, 0.4993895680663527, 'Yes'),
#   Text(-0.9801071204997298, -0.49938965983060607, 'No')])

# %%
plt.pie(testviz, labels=prediction)
# Out:
# ([<matplotlib.patches.Wedge at 0x13ddbfd0>,
# ...
#  [Text(1.075962358309037, 0.22870287165240302, 'Yes'),
#   Text(-1.0759623529558597, -0.22870289683711933, 'No')])

# %%
plt.pie(predviz, labels=prediction)
# Out:
# ([<matplotlib.patches.Wedge at 0x13e1aba8>,
# ...
#  [Text(1.0939740842771233, 0.11498131556922482, 'Yes'),
#   Text(-1.0939740936967814, -0.11498122594713399, 'No')])
